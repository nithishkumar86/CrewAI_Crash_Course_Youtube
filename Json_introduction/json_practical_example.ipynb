# %% [markdown]
# # JAVASCRIPT OBJECT NOTATION

# %% [markdown]
# | Type    | Example                 |
# | ------- | ----------------------- |
# | String  | `"Nithish"`             |
# | Number  | `25`                    |
# | Boolean | `true`                  |
# | Null    | `null`                  |
# | Object  | `{ "name": "Nithish" }` |
# | Array   | `[1, 2, 3]`             |

# %%
sample_data = {
  "name": "Nithish Kumar",
  "age": 22,
  "isStudent": True
}

print(sample_data)
print(type(sample_data))
# Out:
# {'name': 'Nithish Kumar', 'age': 22, 'isStudent': True}
# <class 'dict'>

# %%
# Nested 

nested_sample = {
  "student": {
    "id": 101,
    "name": "Nithish",
    "skills": ["Python", "DSA", "AI"],
    "college": {
      "name": "ABC Engineering College",
      "location": "Chennai"
    }
  }
}

print(nested_sample)
# Out:
# {'student': {'id': 101, 'name': 'Nithish', 'skills': ['Python', 'DSA', 'AI'], 'college': {'name': 'ABC Engineering College', 'location': 'Chennai'}}}

# %% [markdown]
# ## AI Agent Output (Very Important for You)

# %%
crewai_agent = {
  "analysis": {
    "stock_symbol": "AAPL",
    "market_trend": "Bullish",
    "financial_health": "Strong",
    "recommendation": "Buy"
  }
}

# %% [markdown]
# ## There are 4 important JSON methods in Python:
#
# | Method    | Meaning                      |
# | --------- | ---------------------------- |
# | `dump()`  | Write Python → JSON file     |
# | `dumps()` | Convert Python → JSON string |
# | `load()`  | Read JSON file → Python      |
# | `loads()` | Convert JSON string → Python |

# %%
student_data = {
  "name": "Nithish",
  "age": 22,
  "skills": ["Python", "DSA"]
}

# %%
print(type(student_data))
# Out:
# <class 'dict'>

# %% [markdown]
# ## json.dump()
#
# Used when:
#
# You want to store JSON into a file

# %%
import json

data = {
    "name": "Nithish",
    "age": 22,
    "skills": ["Python", "DSA"]
}

with open("student.json", "w") as file:
    json.dump(data, file)

# %%
'''What happens?

Converts Python dictionary → JSON

Writes into file

Nothing is returned

After execution, file contains:'''
# Out:
# 'What happens?\n\nConverts Python dictionary → JSON\n\nWrites into file\n\nNothing is returned\n\nAfter execution, file contains:'

# %% [markdown]
# ## 2.json.dumps()
#
# Notice the extra s
#
# s → string
#
# Used when:
#
# You want JSON as a string, not a file

# %%
data = {
    "name": "Nithish",
    "age": 22
}

print("before converting type is :",type(data))

# it will convert normal python object to json string
json_string = json.dumps(data)

print(json_string)
print(type(json_string))
# Out:
# before converting type is : <class 'dict'>
# {"name": "Nithish", "age": 22}
# <class 'str'>

# %%
print(json_string['name']) # if it will be in the string format we cannot get the keys or values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(json_string['name'])
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# ## json.loads()
#
# Notice the extra s
#
# s means → string
#
# Used when:
#
# You already have JSON in string format

# %%
load_json_sting = json.loads(json_string) # converting into normal python dictionary it is possible to load key

print(load_json_sting['name'])
print(type(load_json_sting))
# Out:
# Nithish
# <class 'dict'>

# %% [markdown]
# # json.load()
#
# will helps to convert json file to python

# %%
with open("student.json",'r') as file:
    data = json.load(file)

print(data)
# Out:
# {'name': 'Nithish', 'age': 22, 'skills': ['Python', 'DSA']}

# %% [markdown]
# ## summary

# %% [markdown]
# | Method | Direction     | Source/Destination |
# | ------ | ------------- | ------------------ |
# | dump   | Python → JSON | File               |
# | dumps  | Python → JSON | String             |
# | load   | JSON → Python | File               |
# | loads  | JSON → Python | String             |

# %% [markdown]
# ## Final Clean Definition (Exam Ready 💯)
#
# 🔹 json.dump()
#
# Converts Python object → JSON format
# Writes directly into a file.
#
# 🔹 json.dumps()
#
# Converts Python object → JSON string
# Returns it as a string.
#
# 🔹 json.load()
#
# Reads JSON from a file
# Converts it → Python object.
#
# 🔹 json.loads()
#
# Reads JSON string
# Converts it → Python object.
