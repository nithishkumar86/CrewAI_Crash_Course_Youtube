# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import Agent, Task, Crew,LLM
from pydantic import BaseModel, Field
from typing import List
import json

# %%
llm = LLM(
    model="groq/llama-3.3-70b-versatile",
    temperature=0.2,
    api_key=os.getenv("GROQ_API_KEY")
    )

# %%
class Blog(BaseModel): # pydantic class 
    title: str
    content: str

# %%
blog_agent = Agent(
    role="Blog Content Generator Agent",
    goal="Generate a blog title and content",
    backstory="""You are an expert content creator, skilled in crafting engaging and informative blog posts.""",
    verbose=True,
    max_tokens = 200,
    llm=llm,
)

task1 = Task(
    description="""
    Topic: {topic}
    Create a blog title and content on a given topic. Make sure the content is under 200 words.""",
    expected_output="A compelling blog title and well-written content.",
    agent=blog_agent,
    output_file="Output//output.json", # the output will be saved in this file
    create_directory=True, # create the directory if it does not exist
    output_pydantic = Blog,
)

# %%
crew = Crew(
    agents=[blog_agent],
    tasks=[task1],
    verbose=True
)

# %%
result = crew.kickoff(inputs={"topic": "The Future of Artificial Intelligence"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  f4bb7c00-9993-42a3-9b8c-325d00ccc3e8                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name:                                                                                                          │
# │      Topic: The Future of Artificial Intelligence                                                               │
# │      Create a blog title and content on a given topic. Make sure the content is under 200 words.                │
# │  ID: 5d791926-7f92-4871-b548-115bf377cca5                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Blog Content Generator Agent                                                                            │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │      Topic: The Future of Artificial Intelligence                                                               │
# │      Create a blog title and content on a given topic. Make sure the content is under 200 words.                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Blog Content Generator Agent                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  {                                                                                                              │
# │    "title": "Revolutionizing the World: The Future of Artificial Intelligence",                                 │
# │    "content": "The future of artificial intelligence (AI) is rapidly unfolding, and its potential to transform  │
# │  the world is vast. As AI technology advances, we can expect significant improvements in areas such as          │
# │  healthcare, finance, and education. AI-powered machines will become increasingly capable of learning,          │
# │  reasoning, and interacting with humans, leading to increased efficiency and productivity. Furthermore, AI      │
# │  will enable the development of innovative solutions to complex problems, such as climate change and            │
# │  sustainable energy. As we move forward, it's essential to consider the ethical implications of AI and ensure   │
# │  that its development is aligned with human values. With its immense potential, the future of AI holds          │
# │  tremendous promise for a brighter, more prosperous world."                                                     │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │                                                                                                                 │
# │      Topic: The Future of Artificial Intelligence                                                               │
# │      Create a blog title and content on a given topic. Make sure the content is under 200 words.                │
# │  Agent:                                                                                                         │
# │  Blog Content Generator Agent                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  f4bb7c00-9993-42a3-9b8c-325d00ccc3e8                                                                           │
# │  Final Output: {                                                                                                │
# │    "title": "Revolutionizing the World: The Future of Artificial Intelligence",                                 │
# │    "content": "The future of artificial intelligence (AI) is rapidly unfolding, and its potential to transform  │
# │  the world is vast. As AI technology advances, we can expect significant improvements in areas such as          │
# │  healthcare, finance, and education. AI-powered machines will become increasingly capable of learning,          │
# │  reasoning, and interacting with humans, leading to increased efficiency and productivity. Furthermore, AI      │
# │  will enable the development of innovative solutions to complex problems, such as climate change and            │
# │  sustainable energy. As we move forward, it's essential to consider the ethical implications of AI and ensure   │
# │  that its development is aligned with human values. With its immense potential, the future of AI holds          │
# │  tremendous promise for a brighter, more prosperous world."                                                     │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
