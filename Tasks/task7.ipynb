# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Dummy Callback Example with CrewAI
# No real database or real email — everything is simulated using Python lists.

from crewai import Agent, Task, Crew,LLM,TaskOutput

# %%
llm = LLM(
    model="groq/llama-3.3-70b-versatile",
    temperature=0.2,
    api_key=os.getenv("GROQ_API_KEY")
    )

# %%
# ---------------------------
# Dummy Database (List)
# ---------------------------
dummy_database = []

def save_to_dummy_database(output: TaskOutput):
    record = {
        "id": len(dummy_database) + 1,
        "data": str(output.raw)
    }
    dummy_database.append(record)
    print("Saved to Dummy Database:", record)


# ---------------------------
# Dummy Email System (List)
# ---------------------------
dummy_email_outbox = []

def send_dummy_email(output):
    email = {
        "to": "customer@example.com",
        "subject": "Order Confirmation",
        "body": str(output.raw)
    }
    dummy_email_outbox.append(email)
    print("Dummy Email Sent:", email)

# %%
# ---------------------------
# Agent 1 → Order Agent
# ---------------------------
order_agent = Agent(
    role="Order Agent",
    goal="Generate order summary",
    backstory="You prepare customer order summaries.",
    verbose = True,
    llm=llm
)

order_task = Task(
    description="Customer ordered a Laptop and Headphones. Create a short order summary.",
    expected_output="Professional order summary.",
    agent=order_agent,
    callback=save_to_dummy_database
)

# %%
# ---------------------------
# Agent 2 → Notification Agent
# ---------------------------

notification_agent = Agent(
    role="Notification Agent",
    goal="Send order confirmation",
    backstory="You notify customers after order processing.",
    llm=llm,
    verbose = True
)

notification_task = Task(
    description="Generate a confirmation email for the customer's order.",
    expected_output="Professional email message.",
    agent=notification_agent,
    callback=send_dummy_email
)

# %%
# ---------------------------
# Crew Execution
# ---------------------------
crew = Crew(
    agents=[order_agent, notification_agent],
    tasks=[order_task, notification_task]
)

result = crew.kickoff()
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Order Agent                                                                                             │
# │                                                                                                                 │
# │  Task: Customer ordered a Laptop and Headphones. Create a short order summary.                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Order Agent                                                                                             │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Order Summary                                                                                                  │
# │                                                                                                                 │
# │  Order Number: #ORD001                                                                                          │
# │  Date: February 15, 2026                                                                                        │
# │  Customer Name: [Not Specified]                                                                                 │
# │                                                                                                                 │
# │  We are pleased to confirm that we have received your order. Below are the details of the items you have        │
# │  ordered:                                                                                                       │
# │                                                                                                                 │
# │  1. Laptop                                                                                                      │
# │     - Quantity: 1                                                                                               │
# │     - Description: [Laptop Model Not Specified]                                                                 │
# │     - Unit Price: [Price Not Specified]                                                                         │
# │     - Total: [Total Price Not Specified]                                                                        │
# │                                                                                                                 │
# │  2. Headphones                                                                                                  │
# │     - Quantity: 1                                                                                               │
# │     - Description: [Headphones Model Not Specified]                                                             │
# │     - Unit Price: [Price Not Specified]                                                                         │
# │     - Total: [Total Price Not Specified]                                                                        │
# │                                                                                                                 │
# │  Subtotal: [Subtotal Not Specified]                                                                             │
# │  Tax (0%): $0.00                                                                                                │
# │  Shipping: [Shipping Cost Not Specified]                                                                        │
# │  Total Due: [Total Amount Not Specified]                                                                        │
# │                                                                                                                 │
# │  Please note that the prices and models are not specified in this summary as the details were not provided.     │
# │  For the actual costs and models, please refer to your original order or contact our customer service.          │
# │                                                                                                                 │
# │  If you have any questions or need further assistance, please do not hesitate to contact us. We appreciate      │
# │  your business and look forward to serving you.                                                                 │
# │                                                                                                                 │
# │  Thank you for choosing our store.                                                                              │
# │                                                                                                                 │
# │  Sincerely,                                                                                                     │
# │  Order Agent                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved to Dummy Database: {'id': 1, 'data': 'Order Summary\n\nOrder Number: #ORD001\nDate: February 15, 2026\nCustomer Name: [Not Specified]\n\nWe are pleased to confirm that we have received your order. Below are the details of the items you have ordered:\n\n1. Laptop\n   - Quantity: 1\n   - Description: [Laptop Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\n2. Headphones\n   - Quantity: 1\n   - Description: [Headphones Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\nSubtotal: [Subtotal Not Specified]\nTax (0%): $0.00\nShipping: [Shipping Cost Not Specified]\nTotal Due: [Total Amount Not Specified]\n\nPlease note that the prices and models are not specified in this summary as the details were not provided. For the actual costs and models, please refer to your original order or contact our customer service.\n\nIf you have any questions or need further assistance, please do not hesitate to contact us. We appreciate your business and look forward to serving you.\n\nThank you for choosing our store.\n\nSincerely,\nOrder Agent'}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Notification Agent                                                                                      │
# │                                                                                                                 │
# │  Task: Generate a confirmation email for the customer's order.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Notification Agent                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Subject: Order Confirmation: #ORD001                                                                           │
# │                                                                                                                 │
# │  Dear Valued Customer,                                                                                          │
# │                                                                                                                 │
# │  We are pleased to confirm that we have received your order. Below are the details of the items you have        │
# │  ordered:                                                                                                       │
# │                                                                                                                 │
# │  1. Laptop                                                                                                      │
# │     - Quantity: 1                                                                                               │
# │     - Description: [Laptop Model Not Specified]                                                                 │
# │     - Unit Price: [Price Not Specified]                                                                         │
# │     - Total: [Total Price Not Specified]                                                                        │
# │                                                                                                                 │
# │  2. Headphones                                                                                                  │
# │     - Quantity: 1                                                                                               │
# │     - Description: [Headphones Model Not Specified]                                                             │
# │     - Unit Price: [Price Not Specified]                                                                         │
# │     - Total: [Total Price Not Specified]                                                                        │
# │                                                                                                                 │
# │  Subtotal: [Subtotal Not Specified]                                                                             │
# │  Tax (0%): $0.00                                                                                                │
# │  Shipping: [Shipping Cost Not Specified]                                                                        │
# │  Total Due: [Total Amount Not Specified]                                                                        │
# │                                                                                                                 │
# │  Please note that the prices and models are not specified in this summary as the details were not provided.     │
# │  For the actual costs and models, please refer to your original order or contact our customer service.          │
# │                                                                                                                 │
# │  If you have any questions or need further assistance, please do not hesitate to contact us. We appreciate      │
# │  your business and look forward to serving you.                                                                 │
# │                                                                                                                 │
# │  Thank you for choosing our store.                                                                              │
# │                                                                                                                 │
# │  Sincerely,                                                                                                     │
# │  Notification Agent                                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Dummy Email Sent: {'to': 'customer@example.com', 'subject': 'Order Confirmation', 'body': 'Subject: Order Confirmation: #ORD001\n\nDear Valued Customer,\n\nWe are pleased to confirm that we have received your order. Below are the details of the items you have ordered:\n\n1. Laptop\n   - Quantity: 1\n   - Description: [Laptop Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\n2. Headphones\n   - Quantity: 1\n   - Description: [Headphones Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\nSubtotal: [Subtotal Not Specified]\nTax (0%): $0.00\nShipping: [Shipping Cost Not Specified]\nTotal Due: [Total Amount Not Specified]\n\nPlease note that the prices and models are not specified in this summary as the details were not provided. For the actual costs and models, please refer to your original order or contact our customer service.\n\nIf you have any questions or need further assistance, please do not hesitate to contact us. We appreciate your business and look forward to serving you.\n\nThank you for choosing our store.\n\nSincerely,\nNotification Agent'}

# %%
print("\nFinal Dummy Database:", dummy_database)
print("\nFinal Dummy Email Outbox:", dummy_email_outbox)
# Out:
# Final Dummy Database: [{'id': 1, 'data': 'Order Summary\n\nOrder Number: #ORD001\nDate: February 15, 2026\nCustomer Name: [Not Specified]\n\nWe are pleased to confirm that we have received your order. Below are the details of the items you have ordered:\n\n1. Laptop\n   - Quantity: 1\n   - Description: [Laptop Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\n2. Headphones\n   - Quantity: 1\n   - Description: [Headphones Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\nSubtotal: [Subtotal Not Specified]\nTax (0%): $0.00\nShipping: [Shipping Cost Not Specified]\nTotal Due: [Total Amount Not Specified]\n\nPlease note that the prices and models are not specified in this summary as the details were not provided. For the actual costs and models, please refer to your original order or contact our customer service.\n\nIf you have any questions or need further assistance, please do not hesitate to contact us. We appreciate your business and look forward to serving you.\n\nThank you for choosing our store.\n\nSincerely,\nOrder Agent'}]
#
# Final Dummy Email Outbox: [{'to': 'customer@example.com', 'subject': 'Order Confirmation', 'body': 'Subject: Order Confirmation: #ORD001\n\nDear Valued Customer,\n\nWe are pleased to confirm that we have received your order. Below are the details of the items you have ordered:\n\n1. Laptop\n   - Quantity: 1\n   - Description: [Laptop Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\n2. Headphones\n   - Quantity: 1\n   - Description: [Headphones Model Not Specified]\n   - Unit Price: [Price Not Specified]\n   - Total: [Total Price Not Specified]\n\nSubtotal: [Subtotal Not Specified]\nTax (0%): $0.00\nShipping: [Shipping Cost Not Specified]\nTotal Due: [Total Amount Not Specified]\n\nPlease note that the prices and models are not specified in this summary as the details were not provided. For the actual costs and models, please refer to your original order or contact our customer service.\n\nIf you have any questions or need further assistance, please do not hesitate to contact us. We appreciate your business and look forward to serving you.\n\nThank you for choosing our store.\n\nSincerely,\nNotification Agent'}]

# %% [markdown]
# # Accessing Task Outputs
#
# Once a task has been executed, its output can be accessed through the output attribute of the Task object. The TaskOutput class provides various ways to interact with and present this output.

# %%
# Create Research Agent
researcher = Agent(
    role='Technology Researcher with specialist in researching recent news',
    goal='Research and gather comprehensive information about emerging technologies',
    backstory="""You are an expert technology researcher with a keen eye for 
    identifying trends and innovations. You excel at finding credible sources 
    and synthesizing complex information into clear insights.""",
    verbose=True, 
    allow_delegation=False,
    llm=llm
)

# Create Research Task
research_task = Task(
    description="""
    Topic {topic}. 
    using the given topic to perform the research. 
    Focus on:
    1. Key features and capabilities
    2. Popular frameworks in 2025
    3. Use cases and applications
    Provide a detailed summary.""",
    agent=researcher,
    markdown = True,  # Enable markdown formatting for the final output
    expected_output="A comprehensive research report on AI agent frameworks stict 500 tokens"
)

# Create Crew
crew = Crew(
    agents=[researcher],
    tasks=[research_task],
    verbose=True
)

# %%
result = crew.kickoff(inputs={"topic": "AI agent frameworks"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  2658a35e-c0bf-436a-ba1c-088b13fff1a6                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name:                                                                                                          │
# │      Topic AI agent frameworks.                                                                                 │
# │      using the given topic to perform the research.                                                             │
# │      Focus on:                                                                                                  │
# │      1. Key features and capabilities                                                                           │
# │      2. Popular frameworks in 2025                                                                              │
# │      3. Use cases and applications                                                                              │
# │      Provide a detailed summary.                                                                                │
# │  ID: 56e64b0f-b8fe-4af7-9803-0c11bd5bb0ed                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher with specialist in researching recent news                                        │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │      Topic AI agent frameworks.                                                                                 │
# │      using the given topic to perform the research.                                                             │
# │      Focus on:                                                                                                  │
# │      1. Key features and capabilities                                                                           │
# │      2. Popular frameworks in 2025                                                                              │
# │      3. Use cases and applications                                                                              │
# │      Provide a detailed summary.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher with specialist in researching recent news                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Introduction to AI Agent Frameworks                                                                          │
# │  AI agent frameworks are **software frameworks** that enable the development of autonomous agents, which are    │
# │  programs that can perform tasks independently without human intervention. These frameworks provide a set of    │
# │  tools, libraries, and APIs that simplify the process of building, deploying, and managing AI-powered agents.   │
# │                                                                                                                 │
# │  ## Key Features and Capabilities                                                                               │
# │  AI agent frameworks typically offer the following key features and capabilities:                               │
# │  * **Autonomy**: The ability of agents to operate independently and make decisions based on their environment   │
# │  and goals.                                                                                                     │
# │  * **Reasoning and Decision-Making**: The ability of agents to reason, learn, and make decisions using various  │
# │  techniques such as machine learning, rule-based systems, and optimization algorithms.                          │
# │  * **Communication**: The ability of agents to communicate with other agents, humans, and systems using         │
# │  various protocols and interfaces.                                                                              │
# │  * **Perception**: The ability of agents to perceive their environment and gather data using sensors, cameras,  │
# │  and other devices.                                                                                             │
# │  * **Action**: The ability of agents to perform actions in their environment, such as moving, manipulating      │
# │  objects, and interacting with other systems.                                                                   │
# │                                                                                                                 │
# │  ## Popular Frameworks in 2025                                                                                  │
# │  Some popular AI agent frameworks in 2025 include:                                                              │
# │  - **Google's TensorFlow Agents**: An open-source framework for building autonomous agents using TensorFlow     │
# │  and other Google technologies.                                                                                 │
# │  - **Microsoft's Bot Framework**: A framework for building conversational AI agents that can interact with      │
# │  humans using natural language.                                                                                 │
# │  - **Amazon's Alexa Skills Kit**: A framework for building voice-activated agents that can interact with        │
# │  Amazon's Alexa virtual assistant.                                                                              │
# │  - **Facebook's ParlAI**: A framework for building conversational AI agents that can interact with humans       │
# │  using natural language.                                                                                        │
# │  - **IBM's Watson Assistant**: A framework for building conversational AI agents that can interact with humans  │
# │  using natural language.                                                                                        │
# │                                                                                                                 │
# │  ## Use Cases and Applications                                                                                  │
# │  AI agent frameworks have a wide range of use cases and applications, including:                                │
# │  * **Virtual Assistants**: AI-powered virtual assistants, such as Amazon's Alexa, Google Assistant, and         │
# │  Apple's Siri, that can perform tasks and answer questions using natural language.                              │
# │  * **Customer Service Chatbots**: AI-powered chatbots that can interact with customers and provide support      │
# │  using natural language.                                                                                        │
# │  * **Robotics and Autonomous Systems**: AI-powered robots and autonomous systems, such as self-driving cars     │
# │  and drones, that can perceive their environment and perform actions using various sensors and devices.         │
# │  * **Smart Homes and Cities**: AI-powered agents that can control and optimize smart home and city systems,     │
# │  such as lighting, heating, and transportation systems.                                                         │
# │  * **Healthcare and Medicine**: AI-powered agents that can assist with healthcare and medical tasks, such as    │
# │  diagnosis, treatment, and patient care.                                                                        │
# │                                                                                                                 │
# │  ### Example Code                                                                                               │
# │  ```python                                                                                                      │
# │  import tensorflow as tf                                                                                        │
# │  from tf_agents.agents import DdpgAgent                                                                         │
# │                                                                                                                 │
# │  # Create a DDPG agent                                                                                          │
# │  agent = DdpgAgent(                                                                                             │
# │      env='CartPole-v0',                                                                                         │
# │      actor_network=tf.keras.models.Sequential([                                                                 │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(2)                                                                               │
# │      ]),                                                                                                        │
# │      critic_network=tf.keras.models.Sequential([                                                                │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(1)                                                                               │
# │      ])                                                                                                         │
# │  )                                                                                                              │
# │                                                                                                                 │
# │  # Train the agent                                                                                              │
# │  agent.train(steps=1000)                                                                                        │
# │  ```                                                                                                            │
# │  This code example demonstrates how to create and train a DDPG agent using TensorFlow Agents. The agent is      │
# │  trained to play the CartPole game, and the code shows how to define the actor and critic networks using        │
# │  Keras.                                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │                                                                                                                 │
# │      Topic AI agent frameworks.                                                                                 │
# │      using the given topic to perform the research.                                                             │
# │      Focus on:                                                                                                  │
# │      1. Key features and capabilities                                                                           │
# │      2. Popular frameworks in 2025                                                                              │
# │      3. Use cases and applications                                                                              │
# │      Provide a detailed summary.                                                                                │
# │  Agent:                                                                                                         │
# │  Technology Researcher with specialist in researching recent news                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  2658a35e-c0bf-436a-ba1c-088b13fff1a6                                                                           │
# │  Final Output: # Introduction to AI Agent Frameworks                                                            │
# │  AI agent frameworks are **software frameworks** that enable the development of autonomous agents, which are    │
# │  programs that can perform tasks independently without human intervention. These frameworks provide a set of    │
# │  tools, libraries, and APIs that simplify the process of building, deploying, and managing AI-powered agents.   │
# │                                                                                                                 │
# │  ## Key Features and Capabilities                                                                               │
# │  AI agent frameworks typically offer the following key features and capabilities:                               │
# │  * **Autonomy**: The ability of agents to operate independently and make decisions based on their environment   │
# │  and goals.                                                                                                     │
# │  * **Reasoning and Decision-Making**: The ability of agents to reason, learn, and make decisions using various  │
# │  techniques such as machine learning, rule-based systems, and optimization algorithms.                          │
# │  * **Communication**: The ability of agents to communicate with other agents, humans, and systems using         │
# │  various protocols and interfaces.                                                                              │
# │  * **Perception**: The ability of agents to perceive their environment and gather data using sensors, cameras,  │
# │  and other devices.                                                                                             │
# │  * **Action**: The ability of agents to perform actions in their environment, such as moving, manipulating      │
# │  objects, and interacting with other systems.                                                                   │
# │                                                                                                                 │
# │  ## Popular Frameworks in 2025                                                                                  │
# │  Some popular AI agent frameworks in 2025 include:                                                              │
# │  - **Google's TensorFlow Agents**: An open-source framework for building autonomous agents using TensorFlow     │
# │  and other Google technologies.                                                                                 │
# │  - **Microsoft's Bot Framework**: A framework for building conversational AI agents that can interact with      │
# │  humans using natural language.                                                                                 │
# │  - **Amazon's Alexa Skills Kit**: A framework for building voice-activated agents that can interact with        │
# │  Amazon's Alexa virtual assistant.                                                                              │
# │  - **Facebook's ParlAI**: A framework for building conversational AI agents that can interact with humans       │
# │  using natural language.                                                                                        │
# │  - **IBM's Watson Assistant**: A framework for building conversational AI agents that can interact with humans  │
# │  using natural language.                                                                                        │
# │                                                                                                                 │
# │  ## Use Cases and Applications                                                                                  │
# │  AI agent frameworks have a wide range of use cases and applications, including:                                │
# │  * **Virtual Assistants**: AI-powered virtual assistants, such as Amazon's Alexa, Google Assistant, and         │
# │  Apple's Siri, that can perform tasks and answer questions using natural language.                              │
# │  * **Customer Service Chatbots**: AI-powered chatbots that can interact with customers and provide support      │
# │  using natural language.                                                                                        │
# │  * **Robotics and Autonomous Systems**: AI-powered robots and autonomous systems, such as self-driving cars     │
# │  and drones, that can perceive their environment and perform actions using various sensors and devices.         │
# │  * **Smart Homes and Cities**: AI-powered agents that can control and optimize smart home and city systems,     │
# │  such as lighting, heating, and transportation systems.                                                         │
# │  * **Healthcare and Medicine**: AI-powered agents that can assist with healthcare and medical tasks, such as    │
# │  diagnosis, treatment, and patient care.                                                                        │
# │                                                                                                                 │
# │  ### Example Code                                                                                               │
# │  ```python                                                                                                      │
# │  import tensorflow as tf                                                                                        │
# │  from tf_agents.agents import DdpgAgent                                                                         │
# │                                                                                                                 │
# │  # Create a DDPG agent                                                                                          │
# │  agent = DdpgAgent(                                                                                             │
# │      env='CartPole-v0',                                                                                         │
# │      actor_network=tf.keras.models.Sequential([                                                                 │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(2)                                                                               │
# │      ]),                                                                                                        │
# │      critic_network=tf.keras.models.Sequential([                                                                │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(64, activation='relu'),                                                          │
# │          tf.keras.layers.Dense(1)                                                                               │
# │      ])                                                                                                         │
# │  )                                                                                                              │
# │                                                                                                                 │
# │  # Train the agent                                                                                              │
# │  agent.train(steps=1000)                                                                                        │
# │  ```                                                                                                            │
# │  This code example demonstrates how to create and train a DDPG agent using TensorFlow Agents. The agent is      │
# │  trained to play the CartPole game, and the code shows how to define the actor and critic networks using        │
# │  Keras.                                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# Accessing the task output
import json


task_output = research_task.output

print(f"Task Description: {task_output.description}")

print(f"Task Summary: {task_output.summary}")

print(f"Raw Output: {task_output.raw}")

if task_output.json_dict:
    print(f"JSON Output: {json.dumps(task_output.json_dict, indent=2)}")
if task_output.pydantic:
    print(f"Pydantic Output: {task_output.pydantic}")
# Out:
# Task Description:
#     Topic AI agent frameworks.
#     using the given topic to perform the research.
#     Focus on:
#     1. Key features and capabilities
#     2. Popular frameworks in 2025
#     3. Use cases and applications
#     Provide a detailed summary.
# Task Summary:
#     Topic AI agent frameworks.
#  ...
# Raw Output: # Introduction to AI Agent Frameworks
# AI agent frameworks are **software frameworks** that enable the development of autonomous agents, which are programs that can perform tasks independently without human intervention. These frameworks provide a set of tools, libraries, and APIs that simplify the process of building, deploying, and managing AI-powered agents.
#
# ## Key Features and Capabilities
# AI agent frameworks typically offer the following key features and capabilities:
# * **Autonomy**: The ability of agents to operate independently and make decisions based on their environment and goals.
# * **Reasoning and Decision-Making**: The ability of agents to reason, learn, and make decisions using various techniques such as machine learning, rule-based systems, and optimization algorithms.
# * **Communication**: The ability of agents to communicate with other agents, humans, and systems using various protocols and interfaces.
# * **Perception**: The ability of agents to perceive their environment and gather data using sensors, cameras, and other devices.
# * **Action**: The ability of agents to perform actions in their environment, such as moving, manipulating objects, and interacting with other systems.
#
# ## Popular Frameworks in 2025
# Some popular AI agent frameworks in 2025 include:
# - **Google's TensorFlow Agents**: An open-source framework for building autonomous agents using TensorFlow and other Google technologies.
# - **Microsoft's Bot Framework**: A framework for building conversational AI agents that can interact with humans using natural language.
# - **Amazon's Alexa Skills Kit**: A framework for building voice-activated agents that can interact with Amazon's Alexa virtual assistant.
# - **Facebook's ParlAI**: A framework for building conversational AI agents that can interact with humans using natural language.
# - **IBM's Watson Assistant**: A framework for building conversational AI agents that can interact with humans using natural language.
#
# ## Use Cases and Applications
# AI agent frameworks have a wide range of use cases and applications, including:
# * **Virtual Assistants**: AI-powered virtual assistants, such as Amazon's Alexa, Google Assistant, and Apple's Siri, that can perform tasks and answer questions using natural language.
# * **Customer Service Chatbots**: AI-powered chatbots that can interact with customers and provide support using natural language.
# * **Robotics and Autonomous Systems**: AI-powered robots and autonomous systems, such as self-driving cars and drones, that can perceive their environment and perform actions using various sensors and devices.
# * **Smart Homes and Cities**: AI-powered agents that can control and optimize smart home and city systems, such as lighting, heating, and transportation systems.
# * **Healthcare and Medicine**: AI-powered agents that can assist with healthcare and medical tasks, such as diagnosis, treatment, and patient care.
#
# ### Example Code
# ```python
# import tensorflow as tf
# from tf_agents.agents import DdpgAgent
#
# # Create a DDPG agent
# agent = DdpgAgent(
#     env='CartPole-v0',
#     actor_network=tf.keras.models.Sequential([
#         tf.keras.layers.Dense(64, activation='relu'),
#         tf.keras.layers.Dense(64, activation='relu'),
#         tf.keras.layers.Dense(2)
#     ]),
#     critic_network=tf.keras.models.Sequential([
#         tf.keras.layers.Dense(64, activation='relu'),
#         tf.keras.layers.Dense(64, activation='relu'),
#         tf.keras.layers.Dense(1)
#     ])
# )
#
# # Train the agent
# agent.train(steps=1000)
# ```
# This code example demonstrates how to create and train a DDPG agent using TensorFlow Agents. The agent is trained to play the CartPole game, and the code shows how to define the actor and critic networks using Keras.
