# %%
# research_crew.py
from crewai import Agent, Task, Crew,LLM
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
llm = LLM(
    model="groq/llama-3.3-70b-versatile",  #llama-3.1-8b-instant
    temperature=0.2 # for output 
)

# %%
# Create Research Agent
researcher = Agent(
    role='Technology Researcher with specialist in researching recent news',
    goal='Research and gather comprehensive information about emerging technologies',
    backstory="""You are an expert technology researcher with a keen eye for 
    identifying trends and innovations. You excel at finding credible sources 
    and synthesizing complex information into clear insights.""",
    verbose=True, 
    allow_delegation=False,
    llm=llm
)

# Create Research Task
research_task = Task(
    description="""Research the latest developments in AI agent frameworks. 
    Focus on:
    1. Key features and capabilities
    2. Popular frameworks in 2024
    3. Use cases and applications
    Provide a detailed summary.""",
    agent=researcher,
    expected_output="A comprehensive research report on AI agent frameworks stict 500 tokens"
)

# Create Crew
crew = Crew(
    agents=[researcher],
    tasks=[research_task],
    verbose=True
)

# %%
# Execute
if __name__ == "__main__":
    result = crew.kickoff()
    print("\n" + "="*50)
    print("RESEARCH RESULTS:")
    print("="*50)
    print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  921416a8-c18e-44cb-904a-b33e35251cfa                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research the latest developments in AI agent frameworks.                                                 │
# │      Focus on:                                                                                                  │
# │      1. Key features and capabilities                                                                           │
# │      2. Popular frameworks in 2024                                                                              │
# │      3. Use cases and applications                                                                              │
# │      Provide a detailed summary.                                                                                │
# │  ID: 47aa7207-fe5f-4941-9497-79c8b177c894                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher with specialist in researching recent news                                        │
# │                                                                                                                 │
# │  Task: Research the latest developments in AI agent frameworks.                                                 │
# │      Focus on:                                                                                                  │
# │      1. Key features and capabilities                                                                           │
# │      2. Popular frameworks in 2024                                                                              │
# │      3. Use cases and applications                                                                              │
# │      Provide a detailed summary.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher with specialist in researching recent news                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Research Report: AI Agent Frameworks                                                                           │
# │                                                                                                                 │
# │  Introduction:                                                                                                  │
# │  AI agent frameworks are software frameworks that enable the development of autonomous agents, which are        │
# │  programs that can perceive their environment, make decisions, and take actions to achieve their goals. These   │
# │  frameworks provide a set of tools, libraries, and APIs that simplify the development of AI agents, allowing    │
# │  developers to focus on the logic and behavior of the agents rather than the underlying infrastructure.         │
# │                                                                                                                 │
# │  Key Features and Capabilities:                                                                                 │
# │  AI agent frameworks typically provide the following key features and capabilities:                             │
# │                                                                                                                 │
# │  1. **Agent Management**: The ability to create, manage, and deploy AI agents, including agent registration,    │
# │  authentication, and authorization.                                                                             │
# │  2. **Knowledge Representation**: The ability to represent and manage knowledge, including ontologies,          │
# │  taxonomies, and semantic reasoning.                                                                            │
# │  3. **Reasoning and Decision-Making**: The ability to reason and make decisions, including rule-based systems,  │
# │  decision trees, and machine learning algorithms.                                                               │
# │  4. **Communication and Interaction**: The ability to communicate and interact with other agents, humans, and   │
# │  external systems, including natural language processing, messaging protocols, and APIs.                        │
# │  5. **Learning and Adaptation**: The ability to learn and adapt, including machine learning, reinforcement      │
# │  learning, and evolutionary algorithms.                                                                         │
# │                                                                                                                 │
# │  Popular Frameworks in 2024:                                                                                    │
# │  Some of the popular AI agent frameworks in 2024 include:                                                       │
# │                                                                                                                 │
# │  1. **JADE (Java Agent Development Framework)**: An open-source framework for developing multi-agent systems,   │
# │  providing a set of tools and APIs for agent management, communication, and interaction.                        │
# │  2. **Apache Airflow**: A platform for programmatically defining, scheduling, and monitoring workflows,         │
# │  including AI agent workflows.                                                                                  │
# │  3. **Microsoft Bot Framework**: A set of tools and APIs for building conversational AI agents, including       │
# │  chatbots, voice assistants, and messaging bots.                                                                │
# │  4. **Google Cloud AI Platform**: A managed platform for building, deploying, and managing AI models,           │
# │  including AI agents, using TensorFlow, scikit-learn, and other machine learning frameworks.                    │
# │  5. **Rasa**: An open-source framework for building conversational AI agents, including chatbots, voice         │
# │  assistants, and messaging bots, using natural language processing and machine learning algorithms.             │
# │                                                                                                                 │
# │  Use Cases and Applications:                                                                                    │
# │  AI agent frameworks have a wide range of use cases and applications, including:                                │
# │                                                                                                                 │
# │  1. **Customer Service**: AI agents can be used to provide customer support, including chatbots, voice          │
# │  assistants, and messaging bots.                                                                                │
# │  2. **Smart Homes and Cities**: AI agents can be used to manage and control smart home and city                 │
# │  infrastructure, including energy management, transportation systems, and public services.                      │
# │  3. **Healthcare**: AI agents can be used to provide personalized healthcare services, including medical        │
# │  diagnosis, treatment recommendations, and patient engagement.                                                  │
# │  4. **Finance**: AI agents can be used to provide financial services, including portfolio management, risk      │
# │  analysis, and investment recommendations.                                                                      │
# │  5. **Manufacturing**: AI agents can be used to optimize manufacturing processes, including supply chain        │
# │  management, quality control, and predictive maintenance.                                                       │
# │                                                                                                                 │
# │  Conclusion:                                                                                                    │
# │  AI agent frameworks are a crucial component of the AI ecosystem, enabling the development of autonomous        │
# │  agents that can perceive, reason, and act in complex environments. The key features and capabilities of AI     │
# │  agent frameworks, including agent management, knowledge representation, reasoning and decision-making,         │
# │  communication and interaction, and learning and adaptation, provide a solid foundation for building a wide     │
# │  range of AI applications. The popular frameworks in 2024, including JADE, Apache Airflow, Microsoft Bot        │
# │  Framework, Google Cloud AI Platform, and Rasa, demonstrate the diversity and richness of the AI agent          │
# │  framework landscape. The use cases and applications of AI agent frameworks, including customer service, smart  │
# │  homes and cities, healthcare, finance, and manufacturing, highlight the potential of AI agents to transform    │
# │  industries and improve human lives.                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Research the latest developments in AI agent frameworks.                                                       │
# │      Focus on:                                                                                                  │
# │      1. Key features and capabilities                                                                           │
# │      2. Popular frameworks in 2024                                                                              │
# │      3. Use cases and applications                                                                              │
# │      Provide a detailed summary.                                                                                │
# │  Agent:                                                                                                         │
# │  Technology Researcher with specialist in researching recent news                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  921416a8-c18e-44cb-904a-b33e35251cfa                                                                           │
# │  Final Output: Research Report: AI Agent Frameworks                                                             │
# │                                                                                                                 │
# │  Introduction:                                                                                                  │
# │  AI agent frameworks are software frameworks that enable the development of autonomous agents, which are        │
# │  programs that can perceive their environment, make decisions, and take actions to achieve their goals. These   │
# │  frameworks provide a set of tools, libraries, and APIs that simplify the development of AI agents, allowing    │
# │  developers to focus on the logic and behavior of the agents rather than the underlying infrastructure.         │
# │                                                                                                                 │
# │  Key Features and Capabilities:                                                                                 │
# │  AI agent frameworks typically provide the following key features and capabilities:                             │
# │                                                                                                                 │
# │  1. **Agent Management**: The ability to create, manage, and deploy AI agents, including agent registration,    │
# │  authentication, and authorization.                                                                             │
# │  2. **Knowledge Representation**: The ability to represent and manage knowledge, including ontologies,          │
# │  taxonomies, and semantic reasoning.                                                                            │
# │  3. **Reasoning and Decision-Making**: The ability to reason and make decisions, including rule-based systems,  │
# │  decision trees, and machine learning algorithms.                                                               │
# │  4. **Communication and Interaction**: The ability to communicate and interact with other agents, humans, and   │
# │  external systems, including natural language processing, messaging protocols, and APIs.                        │
# │  5. **Learning and Adaptation**: The ability to learn and adapt, including machine learning, reinforcement      │
# │  learning, and evolutionary algorithms.                                                                         │
# │                                                                                                                 │
# │  Popular Frameworks in 2024:                                                                                    │
# │  Some of the popular AI agent frameworks in 2024 include:                                                       │
# │                                                                                                                 │
# │  1. **JADE (Java Agent Development Framework)**: An open-source framework for developing multi-agent systems,   │
# │  providing a set of tools and APIs for agent management, communication, and interaction.                        │
# │  2. **Apache Airflow**: A platform for programmatically defining, scheduling, and monitoring workflows,         │
# │  including AI agent workflows.                                                                                  │
# │  3. **Microsoft Bot Framework**: A set of tools and APIs for building conversational AI agents, including       │
# │  chatbots, voice assistants, and messaging bots.                                                                │
# │  4. **Google Cloud AI Platform**: A managed platform for building, deploying, and managing AI models,           │
# │  including AI agents, using TensorFlow, scikit-learn, and other machine learning frameworks.                    │
# │  5. **Rasa**: An open-source framework for building conversational AI agents, including chatbots, voice         │
# │  assistants, and messaging bots, using natural language processing and machine learning algorithms.             │
# │                                                                                                                 │
# │  Use Cases and Applications:                                                                                    │
# │  AI agent frameworks have a wide range of use cases and applications, including:                                │
# │                                                                                                                 │
# │  1. **Customer Service**: AI agents can be used to provide customer support, including chatbots, voice          │
# │  assistants, and messaging bots.                                                                                │
# │  2. **Smart Homes and Cities**: AI agents can be used to manage and control smart home and city                 │
# │  infrastructure, including energy management, transportation systems, and public services.                      │
# │  3. **Healthcare**: AI agents can be used to provide personalized healthcare services, including medical        │
# │  diagnosis, treatment recommendations, and patient engagement.                                                  │
# │  4. **Finance**: AI agents can be used to provide financial services, including portfolio management, risk      │
# │  analysis, and investment recommendations.                                                                      │
# │  5. **Manufacturing**: AI agents can be used to optimize manufacturing processes, including supply chain        │
# │  management, quality control, and predictive maintenance.                                                       │
# │                                                                                                                 │
# │  Conclusion:                                                                                                    │
# │  AI agent frameworks are a crucial component of the AI ecosystem, enabling the development of autonomous        │
# │  agents that can perceive, reason, and act in complex environments. The key features and capabilities of AI     │
# │  agent frameworks, including agent management, knowledge representation, reasoning and decision-making,         │
# │  communication and interaction, and learning and adaptation, provide a solid foundation for building a wide     │
# │  range of AI applications. The popular frameworks in 2024, including JADE, Apache Airflow, Microsoft Bot        │
# │  Framework, Google Cloud AI Platform, and Rasa, demonstrate the diversity and richness of the AI agent          │
# │  framework landscape. The use cases and applications of AI agent frameworks, including customer service, smart  │
# │  homes and cities, healthcare, finance, and manufacturing, highlight the potential of AI agents to transform    │
# │  industries and improve human lives.                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ==================================================
# RESEARCH RESULTS:
# ==================================================
# Research Report: AI Agent Frameworks
#
# Introduction:
# AI agent frameworks are software frameworks that enable the development of autonomous agents, which are programs that can perceive their environment, make decisions, and take actions to achieve their goals. These frameworks provide a set of tools, libraries, and APIs that simplify the development of AI agents, allowing developers to focus on the logic and behavior of the agents rather than the underlying infrastructure.
#
# Key Features and Capabilities:
# AI agent frameworks typically provide the following key features and capabilities:
#
# 1. **Agent Management**: The ability to create, manage, and deploy AI agents, including agent registration, authentication, and authorization.
# 2. **Knowledge Representation**: The ability to represent and manage knowledge, including ontologies, taxonomies, and semantic reasoning.
# 3. **Reasoning and Decision-Making**: The ability to reason and make decisions, including rule-based systems, decision trees, and machine learning algorithms.
# 4. **Communication and Interaction**: The ability to communicate and interact with other agents, humans, and external systems, including natural language processing, messaging protocols, and APIs.
# 5. **Learning and Adaptation**: The ability to learn and adapt, including machine learning, reinforcement learning, and evolutionary algorithms.
#
# Popular Frameworks in 2024:
# Some of the popular AI agent frameworks in 2024 include:
#
# 1. **JADE (Java Agent Development Framework)**: An open-source framework for developing multi-agent systems, providing a set of tools and APIs for agent management, communication, and interaction.
# 2. **Apache Airflow**: A platform for programmatically defining, scheduling, and monitoring workflows, including AI agent workflows.
# 3. **Microsoft Bot Framework**: A set of tools and APIs for building conversational AI agents, including chatbots, voice assistants, and messaging bots.
# 4. **Google Cloud AI Platform**: A managed platform for building, deploying, and managing AI models, including AI agents, using TensorFlow, scikit-learn, and other machine learning frameworks.
# 5. **Rasa**: An open-source framework for building conversational AI agents, including chatbots, voice assistants, and messaging bots, using natural language processing and machine learning algorithms.
#
# Use Cases and Applications:
# AI agent frameworks have a wide range of use cases and applications, including:
#
# 1. **Customer Service**: AI agents can be used to provide customer support, including chatbots, voice assistants, and messaging bots.
# 2. **Smart Homes and Cities**: AI agents can be used to manage and control smart home and city infrastructure, including energy management, transportation systems, and public services.
# 3. **Healthcare**: AI agents can be used to provide personalized healthcare services, including medical diagnosis, treatment recommendations, and patient engagement.
# 4. **Finance**: AI agents can be used to provide financial services, including portfolio management, risk analysis, and investment recommendations.
# 5. **Manufacturing**: AI agents can be used to optimize manufacturing processes, including supply chain management, quality control, and predictive maintenance.
#
# Conclusion:
# AI agent frameworks are a crucial component of the AI ecosystem, enabling the development of autonomous agents that can perceive, reason, and act in complex environments. The key features and capabilities of AI agent frameworks, including agent management, knowledge representation, reasoning and decision-making, communication and interaction, and learning and adaptation, provide a solid foundation for building a wide range of AI applications. The popular frameworks in 2024, including JADE, Apache Airflow, Microsoft Bot Framework, Google Cloud AI Platform, and Rasa, demonstrate the diversity and richness of the AI agent framework landscape. The use cases and applications of AI agent frameworks, including customer service, smart homes and cities, healthcare, finance, and manufacturing, highlight the potential of AI agents to transform industries and improve human lives.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
