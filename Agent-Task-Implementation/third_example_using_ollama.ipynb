# %%
# research_crew.py
from crewai import Agent, Task, Crew,LLM
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
llm = LLM(
    model="ollama/deepseek-v3.1:671b-cloud",
    base_url="http://localhost:11434",
    temperature=0.2
)

# %%
# Create Code Reviewer Agent
code_reviewer = Agent(
    role='Senior Code Reviewer',
    goal='Review code for best practices, bugs, and optimization opportunities',
    backstory="""You are a meticulous senior developer with 15 years of 
    experience. You have a sharp eye for code quality, security issues, 
    and performance bottlenecks.""",
    verbose=True,
    allow_delegation=False,
    llm=llm
)

# Create Code Review Task
review_task = Task(
    description="""Review the following Python function and provide feedback:
```python
def calculate_total(items):
    total = 0
    for item in items:
        total = total + item['price'] * item['quantity']
    return total
```

Provide:
1. Code quality assessment
2. Potential bugs or edge cases
3. Optimization suggestions
4. Best practice recommendations""",
    agent=code_reviewer,
    expected_output="give a precise and concise code review with actionable feedback stict 500 tokens "
)

# %%
# Create Crew
crew = Crew(
    agents=[code_reviewer],
    tasks=[review_task],
    verbose=True
)

# %%
if __name__ == "__main__":
    result = crew.kickoff()
    print("\n" + "="*50)
    print("CODE REVIEW:")
    print("="*50)
    print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  7e075137-1c36-45fd-aa4a-5e486662ee5d                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Review the following Python function and provide feedback:                                               │
# │  ```python                                                                                                      │
# │  def calculate_total(items):                                                                                    │
# │      total = 0                                                                                                  │
# │      for item in items:                                                                                         │
# │          total = total + item['price'] * item['quantity']                                                       │
# │      return total                                                                                               │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  Provide:                                                                                                       │
# │  1. Code quality assessment                                                                                     │
# │  2. Potential bugs or edge cases                                                                                │
# │  3. Optimization suggestions                                                                                    │
# │  4. Best practice recommendations                                                                               │
# │  ID: 343482cf-c913-4b10-a505-fb6aaa14f16b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Code Reviewer                                                                                    │
# │                                                                                                                 │
# │  Task: Review the following Python function and provide feedback:                                               │
# │  ```python                                                                                                      │
# │  def calculate_total(items):                                                                                    │
# │      total = 0                                                                                                  │
# │      for item in items:                                                                                         │
# │          total = total + item['price'] * item['quantity']                                                       │
# │      return total                                                                                               │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  Provide:                                                                                                       │
# │  1. Code quality assessment                                                                                     │
# │  2. Potential bugs or edge cases                                                                                │
# │  3. Optimization suggestions                                                                                    │
# │  4. Best practice recommendations                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Code Reviewer                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Code Review                                                                                                │
# │                                                                                                                 │
# │  #### 1. Code Quality Assessment                                                                                │
# │  The code is straightforward and readable, which is good. However, it lacks several elements of robust code     │
# │  quality:                                                                                                       │
# │  - **Type Hints:** The function signature doesn't specify the expected type for `items` or the return type.     │
# │  This reduces clarity and prevents static type checkers from verifying correctness.                             │
# │  - **Documentation:** There is no docstring explaining the function's purpose, the structure of the items in    │
# │  the list, or the return value.                                                                                 │
# │  - **Naming:** The variable name `items` is acceptable, but more descriptive names like `line_items` or         │
# │  `purchase_items` could better convey that each item is a dictionary with specific keys.                        │
# │                                                                                                                 │
# │  #### 2. Potential Bugs or Edge Cases                                                                           │
# │  - **Missing Keys:** The function will raise a `KeyError` if any dictionary in the `items` list is missing the  │
# │  required `'price'` or `'quantity'` keys.                                                                       │
# │  - **Invalid Data Types:** The function will raise a `TypeError` if the value for `'price'` or `'quantity'` is  │
# │  not a number (e.g., a string or `None`).                                                                       │
# │  - **Negative Values:** The function does not validate if `'price'` or `'quantity'` are negative numbers,       │
# │  which may be undesirable in a financial calculation (e.g., a negative quantity could imply a refund, but the   │
# │  current logic would subtract from the total).                                                                  │
# │  - **Empty List:** If `items` is an empty list, the function correctly returns 0. This is handled properly.     │
# │  - **Non-Dictionary Items:** If an element in the `items` list is not a dictionary, the code will raise a       │
# │  `TypeError` when trying to access the keys.                                                                    │
# │                                                                                                                 │
# │  #### 3. Optimization Suggestions                                                                               │
# │  The current algorithm is O(n) and is already optimal for this task. There is no performance bottleneck. For    │
# │  very large lists, using a generator expression with `sum()` could be slightly more efficient and is            │
# │  considered more Pythonic, but the difference is negligible for most use cases.                                 │
# │                                                                                                                 │
# │  Example:                                                                                                       │
# │  ```python                                                                                                      │
# │  total = sum(item['price'] * item['quantity'] for item in items)                                                │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  #### 4. Best Practice Recommendations                                                                          │
# │  - **Add Type Hints:** Specify the structure of the input data. Using a `TypedDict` is ideal for this case.     │
# │  - **Write a Docstring:** Document the function's behavior, parameters, and return value.                       │
# │  - **Consider Data Validation:** For production code, validate the input data to handle missing keys or         │
# │  invalid types gracefully. This could be done with a try-except block or by using the `.get()` method with a    │
# │  default value, but the correct approach depends on the application's error-handling requirements (e.g.,        │
# │  whether to fail fast or log and skip invalid items).                                                           │
# │  - **Use a More Efficient Construct:** The `sum()` function with a generator expression is more concise and     │
# │  idiomatic.                                                                                                     │
# │                                                                                                                 │
# │  ### Revised Code Example                                                                                       │
# │                                                                                                                 │
# │  Here is an improved version incorporating the recommendations:                                                 │
# │                                                                                                                 │
# │  ```python                                                                                                      │
# │  from typing import List, TypedDict                                                                             │
# │                                                                                                                 │
# │  class LineItem(TypedDict):                                                                                     │
# │      price: float                                                                                               │
# │      quantity: int                                                                                              │
# │                                                                                                                 │
# │  def calculate_total(items: List[LineItem]) -> float:                                                           │
# │      """                                                                                                        │
# │      Calculate the total cost of a list of line items.                                                          │
# │                                                                                                                 │
# │      Args:                                                                                                      │
# │          items: A list of dictionaries, each containing 'price' (float) and 'quantity' (int).                   │
# │                                                                                                                 │
# │      Returns:                                                                                                   │
# │          The total cost (price * quantity) for all items.                                                       │
# │                                                                                                                 │
# │      Raises:                                                                                                    │
# │          KeyError: If any item is missing 'price' or 'quantity'.                                                │
# │          TypeError: If any price or quantity is not a number.                                                   │
# │      """                                                                                                        │
# │      return sum(item['price'] * item['quantity'] for item in items)                                             │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  **Note on Validation:** The above version explicitly documents the potential exceptions. If the requirement    │
# │  is to handle invalid data without raising exceptions, the logic would need to be adjusted (e.g., using         │
# │  `item.get('price', 0)` and logging warnings). The decision should be based on the specific application         │
# │  context.                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Review the following Python function and provide feedback:                                                     │
# │  ```python                                                                                                      │
# │  def calculate_total(items):                                                                                    │
# │      total = 0                                                                                                  │
# │      for item in items:                                                                                         │
# │          total = total + item['price'] * item['quantity']                                                       │
# │      return total                                                                                               │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  Provide:                                                                                                       │
# │  1. Code quality assessment                                                                                     │
# │  2. Potential bugs or edge cases                                                                                │
# │  3. Optimization suggestions                                                                                    │
# │  4. Best practice recommendations                                                                               │
# │  Agent:                                                                                                         │
# │  Senior Code Reviewer                                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  7e075137-1c36-45fd-aa4a-5e486662ee5d                                                                           │
# │  Final Output: ### Code Review                                                                                  │
# │                                                                                                                 │
# │  #### 1. Code Quality Assessment                                                                                │
# │  The code is straightforward and readable, which is good. However, it lacks several elements of robust code     │
# │  quality:                                                                                                       │
# │  - **Type Hints:** The function signature doesn't specify the expected type for `items` or the return type.     │
# │  This reduces clarity and prevents static type checkers from verifying correctness.                             │
# │  - **Documentation:** There is no docstring explaining the function's purpose, the structure of the items in    │
# │  the list, or the return value.                                                                                 │
# │  - **Naming:** The variable name `items` is acceptable, but more descriptive names like `line_items` or         │
# │  `purchase_items` could better convey that each item is a dictionary with specific keys.                        │
# │                                                                                                                 │
# │  #### 2. Potential Bugs or Edge Cases                                                                           │
# │  - **Missing Keys:** The function will raise a `KeyError` if any dictionary in the `items` list is missing the  │
# │  required `'price'` or `'quantity'` keys.                                                                       │
# │  - **Invalid Data Types:** The function will raise a `TypeError` if the value for `'price'` or `'quantity'` is  │
# │  not a number (e.g., a string or `None`).                                                                       │
# │  - **Negative Values:** The function does not validate if `'price'` or `'quantity'` are negative numbers,       │
# │  which may be undesirable in a financial calculation (e.g., a negative quantity could imply a refund, but the   │
# │  current logic would subtract from the total).                                                                  │
# │  - **Empty List:** If `items` is an empty list, the function correctly returns 0. This is handled properly.     │
# │  - **Non-Dictionary Items:** If an element in the `items` list is not a dictionary, the code will raise a       │
# │  `TypeError` when trying to access the keys.                                                                    │
# │                                                                                                                 │
# │  #### 3. Optimization Suggestions                                                                               │
# │  The current algorithm is O(n) and is already optimal for this task. There is no performance bottleneck. For    │
# │  very large lists, using a generator expression with `sum()` could be slightly more efficient and is            │
# │  considered more Pythonic, but the difference is negligible for most use cases.                                 │
# │                                                                                                                 │
# │  Example:                                                                                                       │
# │  ```python                                                                                                      │
# │  total = sum(item['price'] * item['quantity'] for item in items)                                                │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  #### 4. Best Practice Recommendations                                                                          │
# │  - **Add Type Hints:** Specify the structure of the input data. Using a `TypedDict` is ideal for this case.     │
# │  - **Write a Docstring:** Document the function's behavior, parameters, and return value.                       │
# │  - **Consider Data Validation:** For production code, validate the input data to handle missing keys or         │
# │  invalid types gracefully. This could be done with a try-except block or by using the `.get()` method with a    │
# │  default value, but the correct approach depends on the application's error-handling requirements (e.g.,        │
# │  whether to fail fast or log and skip invalid items).                                                           │
# │  - **Use a More Efficient Construct:** The `sum()` function with a generator expression is more concise and     │
# │  idiomatic.                                                                                                     │
# │                                                                                                                 │
# │  ### Revised Code Example                                                                                       │
# │                                                                                                                 │
# │  Here is an improved version incorporating the recommendations:                                                 │
# │                                                                                                                 │
# │  ```python                                                                                                      │
# │  from typing import List, TypedDict                                                                             │
# │                                                                                                                 │
# │  class LineItem(TypedDict):                                                                                     │
# │      price: float                                                                                               │
# │      quantity: int                                                                                              │
# │                                                                                                                 │
# │  def calculate_total(items: List[LineItem]) -> float:                                                           │
# │      """                                                                                                        │
# │      Calculate the total cost of a list of line items.                                                          │
# │                                                                                                                 │
# │      Args:                                                                                                      │
# │          items: A list of dictionaries, each containing 'price' (float) and 'quantity' (int).                   │
# │                                                                                                                 │
# │      Returns:                                                                                                   │
# │          The total cost (price * quantity) for all items.                                                       │
# │                                                                                                                 │
# │      Raises:                                                                                                    │
# │          KeyError: If any item is missing 'price' or 'quantity'.                                                │
# │          TypeError: If any price or quantity is not a number.                                                   │
# │      """                                                                                                        │
# │      return sum(item['price'] * item['quantity'] for item in items)                                             │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  **Note on Validation:** The above version explicitly documents the potential exceptions. If the requirement    │
# │  is to handle invalid data without raising exceptions, the logic would need to be adjusted (e.g., using         │
# │  `item.get('price', 0)` and logging warnings). The decision should be based on the specific application         │
# │  context.                                                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ==================================================
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CODE REVIEW:
# ==================================================
# ### Code Review
#
# #### 1. Code Quality Assessment
# The code is straightforward and readable, which is good. However, it lacks several elements of robust code quality:
# - **Type Hints:** The function signature doesn't specify the expected type for `items` or the return type. This reduces clarity and prevents static type checkers from verifying correctness.
# - **Documentation:** There is no docstring explaining the function's purpose, the structure of the items in the list, or the return value.
# - **Naming:** The variable name `items` is acceptable, but more descriptive names like `line_items` or `purchase_items` could better convey that each item is a dictionary with specific keys.
#
# #### 2. Potential Bugs or Edge Cases
# - **Missing Keys:** The function will raise a `KeyError` if any dictionary in the `items` list is missing the required `'price'` or `'quantity'` keys.
# - **Invalid Data Types:** The function will raise a `TypeError` if the value for `'price'` or `'quantity'` is not a number (e.g., a string or `None`).
# - **Negative Values:** The function does not validate if `'price'` or `'quantity'` are negative numbers, which may be undesirable in a financial calculation (e.g., a negative quantity could imply a refund, but the current logic would subtract from the total).
# - **Empty List:** If `items` is an empty list, the function correctly returns 0. This is handled properly.
# - **Non-Dictionary Items:** If an element in the `items` list is not a dictionary, the code will raise a `TypeError` when trying to access the keys.
#
# #### 3. Optimization Suggestions
# The current algorithm is O(n) and is already optimal for this task. There is no performance bottleneck. For very large lists, using a generator expression with `sum()` could be slightly more efficient and is considered more Pythonic, but the difference is negligible for most use cases.
#
# Example:
# ```python
# total = sum(item['price'] * item['quantity'] for item in items)
# ```
#
# #### 4. Best Practice Recommendations
# - **Add Type Hints:** Specify the structure of the input data. Using a `TypedDict` is ideal for this case.
# - **Write a Docstring:** Document the function's behavior, parameters, and return value.
# - **Consider Data Validation:** For production code, validate the input data to handle missing keys or invalid types gracefully. This could be done with a try-except block or by using the `.get()` method with a default value, but the correct approach depends on the application's error-handling requirements (e.g., whether to fail fast or log and skip invalid items).
# - **Use a More Efficient Construct:** The `sum()` function with a generator expression is more concise and idiomatic.
#
# ### Revised Code Example
#
# Here is an improved version incorporating the recommendations:
#
# ```python
# from typing import List, TypedDict
#
# class LineItem(TypedDict):
#     price: float
#     quantity: int
#
# def calculate_total(items: List[LineItem]) -> float:
#     """
#     Calculate the total cost of a list of line items.
#
#     Args:
#         items: A list of dictionaries, each containing 'price' (float) and 'quantity' (int).
#
#     Returns:
#         The total cost (price * quantity) for all items.
#
#     Raises:
#         KeyError: If any item is missing 'price' or 'quantity'.
#         TypeError: If any price or quantity is not a number.
#     """
#     return sum(item['price'] * item['quantity'] for item in items)
# ```
#
# **Note on Validation:** The above version explicitly documents the potential exceptions. If the requirement is to handle invalid data without raising exceptions, the logic would need to be adjusted (e.g., using `item.get('price', 0)` and logging warnings). The decision should be based on the specific application context.
